# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib.inline
import warnings
warnings.filterwarnings('ignore')
import os
os.getcwd()

#mithilesh@learnbay.co
#8800686128 for whts_app
# please write your name and batch id in the subject along with project name
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
xls_data = pd.read_csv('C:/Users/Sanu/Desktop/DataSet/Lab_monitor.csv',encoding= 'unicode_escape')
xls_data
# Out:
#                                         id  room_id/id        noted_date  \
# 0      __export__.temp_log_196134_bd201015  Room Admin    8/12/2018 9:30
# 1      __export__.temp_log_196131_7bca51bc  Room Admin    8/12/2018 9:30
# 2      __export__.temp_log_196127_522915e3  Room Admin    8/12/2018 9:29
# 3      __export__.temp_log_196128_be0919cf  Room Admin    8/12/2018 9:29
# 4      __export__.temp_log_196126_d30b72fb  Room Admin    8/12/2018 9:29
# ...                                    ...         ...               ...
# 97601   __export__.temp_log_91076_7fbd08ca  Room Admin  28-07-2018 07:07
# 97602  __export__.temp_log_147733_62c03f31  Room Admin  28-07-2018 07:07
# 97603  __export__.temp_log_100386_84093a68  Room Admin  28-07-2018 07:06
# 97604  __export__.temp_log_123297_4d8e690b  Room Admin  28-07-2018 07:06
# 97605  __export__.temp_log_133741_32958703  Room Admin  28-07-2018 07:06
#
#        temp out/in
# 0        29     In
# 1        29     In
# 2        41    Out
# 3        41    Out
# 4        31     In
# ...     ...    ...
# 97601    31     In
# 97602    31     In
# 97603    31     In
# 97604    31     In
# 97605    31     In
#
# [97606 rows x 5 columns]

# %%
xls_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97606 entries, 0 to 97605
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          97606 non-null  object
#  1   room_id/id  97606 non-null  object
#  2   noted_date  97606 non-null  object
#  3   temp        97606 non-null  int64
#  4   out/in      97606 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.7+ MB

# %%
xls_data.id = xls_data.id.str.slice(20,26,1)
xls_data.id=xls_data.id.replace('\_','',regex=True).astype(str)

# %%
xls_data.noted_date=xls_data.noted_date.replace('\/','-',regex=True).astype(str)
xls_data
# Out:
#            id  room_id/id        noted_date  temp out/in
# 0      196134  Room Admin    8-12-2018 9:30    29     In
# 1      196131  Room Admin    8-12-2018 9:30    29     In
# 2      196127  Room Admin    8-12-2018 9:29    41    Out
# 3      196128  Room Admin    8-12-2018 9:29    41    Out
# 4      196126  Room Admin    8-12-2018 9:29    31     In
# ...       ...         ...               ...   ...    ...
# 97601   91076  Room Admin  28-07-2018 07:07    31     In
# 97602  147733  Room Admin  28-07-2018 07:07    31     In
# 97603  100386  Room Admin  28-07-2018 07:06    31     In
# 97604  123297  Room Admin  28-07-2018 07:06    31     In
# 97605  133741  Room Admin  28-07-2018 07:06    31     In
#
# [97606 rows x 5 columns]

# %%
xls_data.loc[18]
# Out:
# id                    196090
# room_id/id        Room Admin
# noted_date    8-12-2018 9:20
# temp                      29
# out/in                    In
# Name: 18, dtype: object

# %%
import datetime

def setSeason(mnt):
    if mnt in [3,4,5]:
        return "summer"
    elif mnt in [6,7,8]:
        return "monsoon"
    elif mnt in [9,10,11]:
        return "post monsoon"
    else:
        return "winter"

def setTimings(hh):
    if hh in range(4,12):
        return "Morning"
    elif hh in range(12,16):
        return "After noon"
    elif hh in range(16,20):
        return "Evening"
    else:
        return "Night"
    
def setinoutcode(x):
    if x=="In":
        return 1
    else:
        return 0

# %%
# set year,month,day, hour,minute,weekday,season,timing  column 
datem= [datetime.datetime.strptime(dd, "%d-%m-%Y %H:%M") for dd in xls_data.noted_date]


years = [yy.year for yy in datem]
xls_data['year'] = years
months = [yy.month for yy in datem]
xls_data['month'] =months

days = [yy.day for yy in datem]
xls_data['days'] = days
weekday = [yy.strftime('%A') for yy in datem]
xls_data['weekday'] = weekday

hours = [yy.hour for yy in datem]
xls_data['hours'] = hours
minutes = [yy.minute for yy in datem]
xls_data['minute'] = minutes

seasons = [setSeason(yy.month) for yy in datem]
xls_data['season'] =seasons

timings = [setTimings(yy.hour) for yy in datem]
xls_data['timing'] =timings
xls_data
# Out:
#            id  room_id/id        noted_date  temp out/in  year  month  days  \
# 0      196134  Room Admin    8-12-2018 9:30    29     In  2018     12     8
# 1      196131  Room Admin    8-12-2018 9:30    29     In  2018     12     8
# 2      196127  Room Admin    8-12-2018 9:29    41    Out  2018     12     8
# 3      196128  Room Admin    8-12-2018 9:29    41    Out  2018     12     8
# 4      196126  Room Admin    8-12-2018 9:29    31     In  2018     12     8
# ...       ...         ...               ...   ...    ...   ...    ...   ...
# 97601   91076  Room Admin  28-07-2018 07:07    31     In  2018      7    28
# 97602  147733  Room Admin  28-07-2018 07:07    31     In  2018      7    28
# 97603  100386  Room Admin  28-07-2018 07:06    31     In  2018      7    28
# 97604  123297  Room Admin  28-07-2018 07:06    31     In  2018      7    28
# 97605  133741  Room Admin  28-07-2018 07:06    31     In  2018      7    28
#
#         weekday  hours  minute   season   timing
# 0      Saturday      9      30   winter  Morning
# 1      Saturday      9      30   winter  Morning
# 2      Saturday      9      29   winter  Morning
# 3      Saturday      9      29   winter  Morning
# 4      Saturday      9      29   winter  Morning
# ...         ...    ...     ...      ...      ...
# 97601  Saturday      7       7  monsoon  Morning
# 97602  Saturday      7       7  monsoon  Morning
# 97603  Saturday      7       6  monsoon  Morning
# 97604  Saturday      7       6  monsoon  Morning
# 97605  Saturday      7       6  monsoon  Morning
#
# [97606 rows x 13 columns]

# %%
inout_codes= [setinoutcode(i) for i in xls_data["out/in"]]
xls_data['inout_code'] =inout_codes
xls_data
# Out:
#            id  room_id/id        noted_date  temp out/in  year  month  days  \
# 0      196134  Room Admin    8-12-2018 9:30    29     In  2018     12     8
# 1      196131  Room Admin    8-12-2018 9:30    29     In  2018     12     8
# 2      196127  Room Admin    8-12-2018 9:29    41    Out  2018     12     8
# 3      196128  Room Admin    8-12-2018 9:29    41    Out  2018     12     8
# 4      196126  Room Admin    8-12-2018 9:29    31     In  2018     12     8
# ...       ...         ...               ...   ...    ...   ...    ...   ...
# 97601   91076  Room Admin  28-07-2018 07:07    31     In  2018      7    28
# 97602  147733  Room Admin  28-07-2018 07:07    31     In  2018      7    28
# 97603  100386  Room Admin  28-07-2018 07:06    31     In  2018      7    28
# 97604  123297  Room Admin  28-07-2018 07:06    31     In  2018      7    28
# 97605  133741  Room Admin  28-07-2018 07:06    31     In  2018      7    28
#
#         weekday  hours  minute   season   timing  inout_code
# 0      Saturday      9      30   winter  Morning           1
# 1      Saturday      9      30   winter  Morning           1
# 2      Saturday      9      29   winter  Morning           0
# 3      Saturday      9      29   winter  Morning           0
# 4      Saturday      9      29   winter  Morning           1
# ...         ...    ...     ...      ...      ...         ...
# 97601  Saturday      7       7  monsoon  Morning           1
# 97602  Saturday      7       7  monsoon  Morning           1
# 97603  Saturday      7       6  monsoon  Morning           1
# 97604  Saturday      7       6  monsoon  Morning           1
# 97605  Saturday      7       6  monsoon  Morning           1
#
# [97606 rows x 14 columns]

# %%
df_season = pd.DataFrame(xls_data,columns=["season","out/in","temp"])
df_season
# Out:
#         season out/in  temp
# 0       winter     In    29
# 1       winter     In    29
# 2       winter    Out    41
# 3       winter    Out    41
# 4       winter     In    31
# ...        ...    ...   ...
# 97601  monsoon     In    31
# 97602  monsoon     In    31
# 97603  monsoon     In    31
# 97604  monsoon     In    31
# 97605  monsoon     In    31
#
# [97606 rows x 3 columns]

# %%
g = sns.factorplot(x='season'
                   ,y= 'temp'
                   ,hue='out/in'
                   ,data=df_season
                   ,kind='bar'
                   ,aspect=1
                   )
g.set_xticklabels(rotation=30);
# Out:
# C:\Users\Sanu\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
df_timing = pd.DataFrame(xls_data,columns=["timing","out/in","temp"])
g = sns.factorplot(x='timing'
                   ,y= 'temp'
                   ,hue='out/in'
                   ,data=df_timing
                   ,kind='bar'
                   ,aspect=1
                   )
g.set_xticklabels(rotation=30);
# Out:
# C:\Users\Sanu\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
X= xls_data.iloc[:,2]
# Y= xls_data.target
X
# Out:
# 0          8-12-2018 9:30
# 1          8-12-2018 9:30
# 2          8-12-2018 9:29
# 3          8-12-2018 9:29
# 4          8-12-2018 9:29
#                ...
# 97601    28-07-2018 07:07
# 97602    28-07-2018 07:07
# 97603    28-07-2018 07:06
# 97604    28-07-2018 07:06
# 97605    28-07-2018 07:06
# Name: noted_date, Length: 97606, dtype: object

# %%
# df_month = pd.DataFrame().assign(inout=xls_data["inout_code"],month=xls_data["month"],temp=xls_data["temp"])
# df_month = df_month.drop_duplicates()
# df_month.corr()


#graph  for seasons and period with respect to temp.

df_season = pd.DataFrame(xls_data.season,xls_data.temp)
#df_season
sns.histplot(df_season,x='temp',y='season',bins=30)

# %%
X = xls_data.drop(["temp","out/in"],axis=1)
y = xls_data["temp"]
X
# Split the dataset into the training set and test set

# xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 1/3, )
# print ( xTrain.shape, xTest.shape, yTrain.shape, yTest.shape)
# Out:
#       id  room_id/id        noted_date  inout_code
# 0         Room Admin    8/12/2018 9:30           1
# 1         Room Admin    8/12/2018 9:30           1
# 2         Room Admin    8/12/2018 9:29           0
# 3         Room Admin    8/12/2018 9:29           0
# 4         Room Admin    8/12/2018 9:29           1
# ...   ..         ...               ...         ...
# 97601     Room Admin  28-07-2018 07:07           1
# 97602     Room Admin  28-07-2018 07:07           1
# 97603     Room Admin  28-07-2018 07:06           1
# 97604     Room Admin  28-07-2018 07:06           1
# 97605     Room Admin  28-07-2018 07:06           1
#
# [97606 rows x 4 columns]

# %%
# Creating a LinearRegression object and fitting it on our training set.
linearRegressor = LinearRegression()
linearRegressor.fit(xTrain, yTrain) # fit() is running the training process

# Predicting the test set results
yPrediction = linearRegressor.predict(xTest)

# %%
yPrediction
# Out:
# array([ 9.83333333, 10.08064516, 10.08064516, 10.08064516, 10.08064516,
#        10.08064516, 10.08064516,  9.83333333, 10.08064516, 10.08064516,
#        10.08064516,  9.83333333,  9.83333333,  9.83333333, 10.08064516,
#         9.83333333, 10.08064516,  9.83333333, 10.08064516, 10.08064516,
#         9.83333333, 10.08064516, 10.08064516, 10.08064516, 10.08064516,
#        10.08064516, 10.08064516, 10.08064516, 10.08064516, 10.08064516,
#         9.83333333, 10.08064516, 10.08064516,  9.83333333,  9.83333333,
#         9.83333333,  9.83333333, 10.08064516,  9.83333333, 10.08064516,
#         9.83333333, 10.08064516,  9.83333333, 10.08064516, 10.08064516,
#         9.83333333, 10.08064516,  9.83333333, 10.08064516,  9.83333333,
#        10.08064516, 10.08064516])
